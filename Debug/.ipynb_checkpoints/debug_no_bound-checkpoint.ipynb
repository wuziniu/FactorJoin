# %%
import pickle
import sys
sys.path.append("../")
from Join_scheme.data_prepare import process_stats_data
from BayesCard.Models.Bayescard_BN import Bayescard_BN
import time
import pandas as pd
import numpy as np
from BayesCard.Evaluation.cardinality_estimation import parse_query_single_table

# %%
from Join_scheme.data_prepare import process_stats_data
data_path = "/home/ubuntu/End-to-End-CardEst-Benchmark/datasets/stats_simplified/{}.csv"
model_folder = "/home/ubuntu/data_CE/saved_models"
data, null_values, key_attrs, table_buckets, equivalent_keys, schema, bin_size, all_bin_means, all_bin_width = process_stats_data(data_path,
                                                model_folder, 200, "sub_optimal", return_bin_means=True)
# Out:
# bucketizing equivalent key group: {'comments.PostId', 'postLinks.PostId', 'postLinks.RelatedPostId', 'votes.PostId', 'postHistory.PostId', 'posts.Id', 'tags.ExcerptPostId'}
# bucketizing equivalent key group: {'posts.OwnerUserId', 'postHistory.UserId', 'votes.UserId', 'users.Id', 'badges.UserId', 'comments.UserId'}

# %%
all_bin_means['tags.ExcerptPostId'] = np.ones(48)
all_bin_width['tags.ExcerptPostId'] = np.ones(48) * len(data["tags"]["tags.ExcerptPostId"])/48
all_bin_means['posts.Id'] = np.ones(48)
all_bin_width['posts.Id'] = np.ones(48) * len(data["posts"]["posts.Id"])/48
all_bin_means['users.Id'] = np.ones(107)
all_bin_width['users.Id'] = np.ones(107) * len(data["users"]["users.Id"])/107

# %%
def learn_histogram(data, key_attrs, all_bin_means, all_bin_width, all_bin_size, bin_size=50):
    all_histogram = dict()
    all_boundary = dict()
    for table in data:
        all_histogram[table] = dict()
        all_boundary[table] = dict()
        for attr in data[table]:
            if attr in key_attrs[table]:
                assert all_bin_size[table][attr] == len(all_bin_means[attr]) == len(all_bin_width[attr])
            else:
                hist, curr_bins = np.histogram(data[table][attr].values, bins=bin_size)
                all_histogram[table][attr] = hist/np.sum(hist)
                all_boundary[table][attr] = curr_bins
    return all_histogram, all_boundary

# %%
all_histogram, all_boundary = learn_histogram(data, key_attrs, all_bin_means, all_bin_width, bin_size, bin_size=50)

# %%
import numpy as np
import copy

from Join_scheme.join_graph import process_condition, get_join_hyper_graph
from Join_scheme.data_prepare import identify_key_values
from BayesCard.Evaluation.cardinality_estimation import timestamp_transorform, construct_table_query

OPS = {
    '>': np.greater,
    '<': np.less,
    '>=': np.greater_equal,
    '<=': np.less_equal,
    '=': np.equal,
    '==': np.equal
}

class Bound_ensemble:
    """
    This the class where we store all the trained models and perform inference on the bound.
    """
    def __init__(self, hist, boundary, all_bin_means, all_key_size, schema):
        self.hist = hist
        self.boundary = boundary
        self.schema = schema
        self.all_bin_means = all_bin_means
        self.all_key_size = all_key_size
        self.all_keys, self.equivalent_keys = identify_key_values(schema)

    def parse_query_simple(self, query):
        """
        If your selection query contains no aggregation and nested sub-queries, you can use this function to parse a
        join query. Otherwise, use parse_query function.
        """
        query = query.replace(" where ", " WHERE ")
        query = query.replace(" from ", " FROM ")
        query = query.replace(" and ", " AND ")
        query = query.split(";")[0]
        query = query.strip()
        tables_all = {}
        join_cond = []
        table_probs = {}
        join_keys = {}
        tables_str = query.split(" WHERE ")[0].split(" FROM ")[-1]
        for table_str in tables_str.split(","):
            table_str = table_str.strip()
            if " as " in table_str:
                tables_all[table_str.split(" as ")[-1]] = table_str.split(" as ")[0]
            else:
                tables_all[table_str.split(" ")[-1]] = table_str.split(" ")[0]

        # processing conditions
        conditions = query.split(" WHERE ")[-1].split(" AND ")
        for cond in conditions:
            table, cond, join, join_key = process_condition(cond, tables_all)
            if table not in table_probs:
                table_probs[table] = 1
            if not join:
                attr = cond[0]
                op = cond[1]
                value = cond[2]
                if "Date" in attr:
                    assert "::timestamp" in value
                    value = timestamp_transorform(value.strip().split("::timestamp")[0])
                curr_prob = 0
                for i in range(0, len(self.boundary[table][attr])-1):
                    if OPS[op](self.boundary[table][attr][i], value):
                        curr_prob += self.hist[table][attr][i]
                table_probs[table] *= curr_prob
                #construct_table_query(self.bns[table], table_query[table], attr, op, value)
            else:
                join_cond.append(cond)
                for tab in join_key:
                    if tab in join_keys:
                        join_keys[tab].add(join_key[tab])
                    else:
                        join_keys[tab] = set([join_key[tab]])
        final_probs = 1
        for table in table_probs:
            final_probs *= table_probs[table]
        #print(final_probs)
        return tables_all, final_probs, join_cond, join_keys
    
    def multiply_hist_oned(self, all_probs, all_means):
        all_probs = np.stack(all_probs, axis=0)
        all_means = np.stack(all_means, axis=0)
        multiplier = np.prod(all_means, axis=0)
        min_number = np.amin(all_probs, axis=0)
        multiplier = multiplier * min_number
        return np.sum(multiplier)

    def eliminate_one_key_group(self, key_group, relevant_keys, res):
        all_means = []
        all_probs = []
        for key in relevant_keys:
            if res:
                hist = self.all_bin_means[key] * self.all_key_size[key]
                #print("key", np.sum(hist))
                ratio = res/np.sum(hist)
                all_means.append(self.all_bin_means[key]*ratio)
                all_probs.append(self.all_key_size[key])
            else:
                #print(key, np.sum(self.all_bin_means[key] * self.all_key_size[key]))
                all_means.append(self.all_bin_means[key])
                all_probs.append(self.all_key_size[key])
        return self.multiply_hist_oned(all_probs, all_means)
        

    def get_cardinality(self, query_str):
        tables_all, table_probs, join_cond, join_keys = self.parse_query_simple(query_str)
        equivalent_group = get_join_hyper_graph(join_keys, self.equivalent_keys)
        res = None
        for key_group in equivalent_group:
            res = self.eliminate_one_key_group(key_group, equivalent_group[key_group], res)
        if res <= 1:
            res = 1
        return res * table_probs

# %%
BE = Bound_ensemble(all_histogram, all_boundary, all_bin_means, all_bin_width, schema)

# %%
query_file = "/home/ubuntu/End-to-End-CardEst-Benchmark/workloads/stats_CEB/sub_plan_queries/stats_CEB_sub_queries.sql"
with open(query_file, "r") as f:
    queries = f.readlines()

# %%
qerror = []
latency = []
pred = []
for i, query_str in enumerate(queries):
    #if i == 10: break
    query = query_str.split("||")[0][:-1]
    print("========================")
    true_card = int(query_str.split("||")[-1])
    t = time.time()
    res = BE.get_cardinality(query)
    pred.append(res)
    latency.append(time.time() - t)
    qerror.append(res/true_card)
    print(f"estimating query {i}: predicted {res}, true_card {true_card}, qerror {res/true_card}, latency {time.time() - t}")
# Out:
# ========================
# 0.9999999999999997
# badges.UserId 72862.0
# users.Id 40325.00000000001
# estimating query 0: predicted 47733.7567245126, true_card 79851, qerror 0.5977853342414321, latency 0.0025177001953125
# ========================
# 0.9173001348211466
# comments.UserId 170648.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 1: predicted 14362954.23812714, true_card 10220614, qerror 1.4052926994530015, latency 0.0025436878204345703
# ========================
# 0.12985859910437597
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 2: predicted 34153855.38067131, true_card 1458075, qerror 23.423935929682155, latency 0.0014815330505371094
# ========================
# 0.13792920434226688
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 3: predicted 36276489.43055708, true_card 1709781, qerror 21.21703857427184, latency 0.0017466545104980469
# ========================
# 0.9173001348211468
# comments.UserId 170648.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 4: predicted 10393431.07729698, true_card 7491903, qerror 1.3872885270000133, latency 0.0010433197021484375
# ========================
# 0.016276918077011798
# badges.UserId 72862.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 5: predicted 59216.72628281309, true_card 428612, qerror 0.1381592822478444, latency 0.013226747512817383
# ========================
# 0.9759785202010376
# comments.UserId 170648.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 6: predicted 54248508.49000834, true_card 55900138, qerror 0.9704539278598622, latency 0.0032312870025634766
# ========================
# 0.9759785202010376
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 7: predicted 9273.74789895026, true_card 10972, qerror 0.8452194585262723, latency 0.0016520023345947266
# ========================
# 0.9759785202010376
# posts.OwnerUserId 90361.0
# comments.UserId 170648.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# estimating query 8: predicted 32783915856.55438, true_card 699302, qerror 46880.91247637555, latency 0.0020456314086914062
# ========================
# 0.8850665735036081
# comments.UserId 170648.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 9: predicted 49195285.0735311, true_card 36337035, qerror 1.3538607394227706, latency 0.006292819976806641
# ========================
# 0.8259269058474361
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 10: predicted 7847.957459362338, true_card 9405, qerror 0.8344452375717532, latency 0.0028390884399414062
# ========================
# 0.7576228620862657
# posts.OwnerUserId 90361.0
# comments.UserId 170648.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# estimating query 11: predicted 25449170906.4681, true_card 481420, qerror 52862.72050697541, latency 0.0034804344177246094
# ========================
# 0.9996955727581116
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 12: predicted 71472.55235720197, true_card 173407, qerror 0.41216647746170554, latency 0.0009276866912841797
# ========================
# 1
# posts.Id 91976.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# estimating query 13: predicted 276501.8619857278, true_card 704085, qerror 0.3927109113043564, latency 0.0038492679595947266
# ========================
# 0.9996955727581116
# posts.Id 91976.0
# postHistory.PostId 259700.0
# estimating query 14: predicted 87232.4759559357, true_card 303005, qerror 0.28789120957058695, latency 0.0016705989837646484
# ========================
# 0.9996955727581116
# posts.Id 91976.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# estimating query 15: predicted 276417.68728650647, true_card 698213, qerror 0.39589306885793657, latency 0.002053499221801758
# ========================
# 0.00011471457550328592
# comments.UserId 170648.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 16: predicted 6376.261868791786, true_card 780683, qerror 0.00816754286796534, latency 0.003142118453979492
# ========================
# 0.9875505579300649
# comments.UserId 170648.0
# users.Id 40325.00000000001
# estimating query 17: predicted 154131.44740331924, true_card 169446, qerror 0.9096198635749397, latency 0.0011224746704101562
# ========================
# 0.00011616071155256199
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 18: predicted 8.367583754022212, true_card 11630, qerror 0.0007194826959606372, latency 0.004006862640380859
# ========================
# 0.00011471457550328592
# comments.UserId 170648.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 19: predicted 6376.261868791786, true_card 780683, qerror 0.00816754286796534, latency 0.002476215362548828
# ========================
# 0.003913095179434478
# comments.UserId 170648.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 20: predicted 217504.35349748828, true_card 1227386, qerror 0.17720941374391452, latency 0.0021893978118896484
# ========================
# 0.8942389749952684
# comments.UserId 170648.0
# users.Id 40325.00000000001
# estimating query 21: predicted 139567.8899006222, true_card 53564, qerror 2.605628591976368, latency 0.0016672611236572266
# ========================
# 0.004158637747599018
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 22: predicted 299.56556903430555, true_card 32260, qerror 0.00928597548153458, latency 0.0025572776794433594
# ========================
# 0.00381471896654489
# comments.UserId 170648.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 23: predicted 212036.23846248077, true_card 326559, qerror 0.6493045313786506, latency 0.007734775543212891
# ========================
# 1
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 24: predicted 263008038.0985751, true_card 263105194, qerror 0.999630733624267, latency 0.0015697479248046875
# ========================
# 0.9583558486374181
# comments.UserId 170648.0
# users.Id 40325.00000000001
# estimating query 25: predicted 149574.89810702138, true_card 49655, qerror 3.0122827128591556, latency 0.0023381710052490234
# ========================
# 0.9583558486374181
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# estimating query 26: predicted 216199.85053423984, true_card 126748, qerror 1.705745657006342, latency 0.0013532638549804688
# ========================
# 0.9583558486374181
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 27: predicted 252055291.5504223, true_card 1018612, qerror 247.4497566791107, latency 0.0023114681243896484
# ========================
# 0.987550557930065
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 28: predicted 11189400.578463415, true_card 10984892, qerror 1.0186172589100935, latency 0.0010578632354736328
# ========================
# 0.9833383150047337
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 29: predicted 153474.023746695, true_card 64566, qerror 2.377009939390623, latency 0.0012230873107910156
# ========================
# 0.9957346559206445
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 30: predicted 29020.013473865492, true_card 23267, qerror 1.2472606470050067, latency 0.0018017292022705078
# ========================
# 0.9833383150047337
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 31: predicted 11141673.934954528, true_card 315516, qerror 35.31254812736764, latency 0.0018837451934814453
# ========================
# 0.9764794780744701
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 32: predicted 11063960.16799971, true_card 447953, qerror 24.698930843190492, latency 0.0019953250885009766
# ========================
# 0.9729989772685578
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 33: predicted 151860.31690640035, true_card 20126, qerror 7.545479325568933, latency 0.0019927024841308594
# ========================
# 0.9958768754600434
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 34: predicted 29024.158366207106, true_card 40, qerror 725.6039591551777, latency 0.0008528232574462891
# ========================
# 0.9727261161624665
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 35: predicted 11021432.856752595, true_card 200, qerror 55107.16428376298, latency 0.0031707286834716797
# ========================
# 0.8891355821738781
# comments.UserId 170648.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 36: predicted 13921957.703346392, true_card 10223864, qerror 1.361711942113705, latency 0.0023610591888427734
# ========================
# 0.905880259931947
# comments.UserId 170648.0
# users.Id 40325.00000000001
# estimating query 37: predicted 141384.7974832432, true_card 132504, qerror 1.067022863334263, latency 0.0016849040985107422
# ========================
# 0.981515572754254
# badges.UserId 72862.0
# users.Id 40325.00000000001
# estimating query 38: predicted 46851.42557117222, true_card 79610, qerror 0.5885118147364932, latency 0.0009570121765136719
# ========================
# 0.8891355821738778
# comments.UserId 170648.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 39: predicted 13921957.703346387, true_card 10223864, qerror 1.3617119421137045, latency 0.0030524730682373047
# ========================
# 0.9003443672165329
# comments.UserId 170648.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 40: predicted 14097463.255478512, true_card 10234398, qerror 1.3774589629481395, latency 0.0016715526580810547
# ========================
# 0.8974362104245073
# comments.UserId 170648.0
# users.Id 40325.00000000001
# estimating query 41: predicted 140066.8967822857, true_card 45485, qerror 3.0794085254982018, latency 0.0017981529235839844
# ========================
# 0.9602610777517915
# badges.UserId 72862.0
# users.Id 40325.00000000001
# estimating query 42: predicted 45836.8686774223, true_card 55035, qerror 0.8328676056586227, latency 0.0024335384368896484
# ========================
# 0.880847616085218
# comments.UserId 170648.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 43: predicted 13792185.916403633, true_card 245567, qerror 56.16465533399696, latency 0.0025870800018310547
# ========================
# 0.9969557275811082
# posts.Id 91976.0
# tags.ExcerptPostId 1032.0
# estimating query 44: predicted 1028.8583108637035, true_card 596, qerror 1.726272333663932, latency 0.0014202594757080078
# ========================
# 0.9969557275811082
# votes.UserId 29638.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 45: predicted 2858697.6400815505, true_card 2734033, qerror 1.045597342856341, latency 0.0015072822570800781
# ========================
# 0.9969557275811082
# votes.UserId 29638.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# key 91976.0
# key 1032.0
# estimating query 46: predicted 89122232.13016735, true_card 70752, qerror 1259.6425843816055, latency 0.0022504329681396484
# ========================
# 0.9969557275811082
# postLinks.PostId 9502.0
# posts.Id 91976.0
# estimating query 47: predicted 9473.07332347569, true_card 11091, qerror 0.8541225609481282, latency 0.0005393028259277344
# ========================
# 0.9950057932288583
# postHistory.PostId 259700.0
# posts.Id 91976.0
# estimating query 48: predicted 86823.25029647266, true_card 302620, qerror 0.2869051956132201, latency 0.0007646083831787109
# ========================
# 0.9980441113900003
# postHistory.PostId 259700.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 49: predicted 34099.04909135641, true_card 63543, qerror 0.5366295121627309, latency 0.0017552375793457031
# ========================
# 0.9950057932288583
# postHistory.PostId 259700.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 50: predicted 33995.24229669716, true_card 63500, qerror 0.5353581464046796, latency 0.0013456344604492188
# ========================
# 0.9984887361920503
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 51: predicted 9487.639971296861, true_card 11050, qerror 0.8586099521535622, latency 0.0009984970092773438
# ========================
# 0.9984887361920501
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# estimating query 52: predicted 71925.6796542109, true_card 90414, qerror 0.7955148500697999, latency 0.0014557838439941406
# ========================
# 0.9984887361920501
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# estimating query 53: predicted 56331.36310768172, true_card 10895, qerror 5.170386701026317, latency 0.002125978469848633
# ========================
# 0.977189701661303
# postHistory.PostId 259700.0
# posts.Id 91976.0
# estimating query 54: predicted 85268.63525000635, true_card 291926, qerror 0.29208989692595505, latency 0.0014922618865966797
# ========================
# 0.9760992233829453
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# estimating query 55: predicted 70312.86133433373, true_card 69617, qerror 1.009995566231434, latency 0.0019202232360839844
# ========================
# 0.9760992233829453
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# estimating query 56: predicted 18502.88879353668, true_card 251068, qerror 0.07369672277445426, latency 0.0029039382934570312
# ========================
# 0.3318438553075353
# votes.PostId 328064.0
# posts.Id 91976.0
# estimating query 57: predicted 65163.071720556356, true_card 288438, qerror 0.2259170834652728, latency 0.0011966228485107422
# ========================
# 0.9821202727836326
# votes.UserId 29638.0
# users.Id 40325.00000000001
# estimating query 58: predicted 28623.23148006298, true_card 31965, qerror 0.8954553880826835, latency 0.002565145492553711
# ========================
# 0.32591057769620885
# votes.UserId 29638.0
# users.Id 40325.00000000001
# key 328064.0
# key 91976.0
# estimating query 59: predicted 1801.5283627402614, true_card 26836, qerror 0.06713103155240205, latency 0.0029735565185546875
# ========================
# 0.9927807254066283
# votes.UserId 29638.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 60: predicted 2846726.126669938, true_card 2704241, qerror 1.0526895075808473, latency 0.0018396377563476562
# ========================
# 0.9821202727836329
# votes.UserId 29638.0
# users.Id 40325.00000000001
# estimating query 61: predicted 28623.231480062987, true_card 32918, qerror 0.8695313044554039, latency 0.0014955997467041016
# ========================
# 0.9750300768506908
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# estimating query 62: predicted 70235.84585264126, true_card 86112, qerror 0.8156336614251354, latency 0.0016109943389892578
# ========================
# 0.9750300768506908
# votes.UserId 29638.0
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 63: predicted 2795827.4400653746, true_card 2488080, qerror 1.1236887238615216, latency 0.0019252300262451172
# ========================
# 1
# badges.UserId 72862.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 64: predicted 993606.9525606718, true_card 1056687, qerror 0.940303942946844, latency 0.0015246868133544922
# ========================
# 0.998735275883447
# votes.UserId 29638.0
# users.Id 40325.00000000001
# estimating query 65: predicted 29107.464514393923, true_card 20334, qerror 1.4314677148811805, latency 0.0006132125854492188
# ========================
# 0.998735275883447
# badges.UserId 72862.0
# users.Id 40325.00000000001
# estimating query 66: predicted 47673.386691209445, true_card 62294, qerror 0.7652966046683379, latency 0.0019185543060302734
# ========================
# 0.998735275883447
# badges.UserId 72862.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 67: predicted 992350.3138853937, true_card 144017, qerror 6.890508161435064, latency 0.0018777847290039062
# ========================
# 0.005302769266944469
# badges.UserId 72862.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 68: predicted 5268.868411461081, true_card 29072, qerror 0.18123515449439603, latency 0.0006668567657470703
# ========================
# 0.005296062726768048
# votes.UserId 29638.0
# users.Id 40325.00000000001
# estimating query 69: predicted 154.3501682656048, true_card 433, qerror 0.35646690130624664, latency 0.002307415008544922
# ========================
# 0.998735275883447
# badges.UserId 72862.0
# users.Id 40325.00000000001
# estimating query 70: predicted 47673.386691209445, true_card 62294, qerror 0.7652966046683379, latency 0.0010075569152832031
# ========================
# 0.005296062726768048
# badges.UserId 72862.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 71: predicted 5262.204746514162, true_card 4582, qerror 1.1484514942195903, latency 0.0018401145935058594
# ========================
# 0.9858863157747287
# comments.PostId 153297.0
# posts.Id 91976.0
# estimating query 72: predicted 70485.26895848106, true_card 173065, qerror 0.4072762774592266, latency 0.0012786388397216797
# ========================
# 0.987550557930065
# postLinks.PostId 9502.0
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 73: predicted 31970.37929207736, true_card 35157, qerror 0.9093602779553819, latency 0.0014619827270507812
# ========================
# 0.0
# votes.PostId 328064.0
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 74: predicted 0.0, true_card 670344, qerror 0.0, latency 0.0018520355224609375
# ========================
# 0.998314777768113
# postLinks.PostId 9502.0
# posts.Id 91976.0
# estimating query 75: predicted 9485.987018352609, true_card 11077, qerror 0.8563678810465477, latency 0.0013349056243896484
# ========================
# 0.0
# votes.PostId 328064.0
# posts.Id 91976.0
# estimating query 76: predicted 0.0, true_card 261948, qerror 0.0, latency 0.0008549690246582031
# ========================
# 0.0
# votes.PostId 328064.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 77: predicted 0.0, true_card 45464, qerror 0.0, latency 0.002354860305786133
# ========================
# 0.9858863157747287
# postLinks.PostId 9502.0
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 78: predicted 31916.50209813249, true_card 35034, qerror 0.9110150738748783, latency 0.0015246868133544922
# ========================
# 0.0
# votes.PostId 328064.0
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 79: predicted 0.0, true_card 670154, qerror 0.0, latency 0.0020170211791992188
# ========================
# 0.0
# postLinks.PostId 9502.0
# posts.Id 91976.0
# votes.PostId 328064.0
# comments.PostId 153297.0
# estimating query 80: predicted 0.0, true_card 176221, qerror 0.0, latency 0.0010676383972167969
# ========================
# 0.0
# votes.PostId 328064.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 81: predicted 0.0, true_card 45455, qerror 0.0, latency 0.001020669937133789
# ========================
# 0.0
# postLinks.PostId 9502.0
# posts.Id 91976.0
# votes.PostId 328064.0
# comments.PostId 153297.0
# estimating query 82: predicted 0.0, true_card 176191, qerror 0.0, latency 0.0011589527130126953
# ========================
# 0.9875505579300649
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 83: predicted 70604.25281499064, true_card 170249, qerror 0.4147117035341802, latency 0.0007517337799072266
# ========================
# 0.9875505579300649
# posts.Id 91976.0
# postLinks.RelatedPostId 10807.0
# comments.PostId 153297.0
# estimating query 84: predicted 43099.2555518554, true_card 32792, qerror 1.3143222600590205, latency 0.00523686408996582
# ========================
# 1
# posts.Id 91976.0
# postLinks.RelatedPostId 10807.0
# estimating query 85: predicted 10807.0, true_card 11102, qerror 0.9734282111331292, latency 0.0009529590606689453
# ========================
# 0.9760942343459389
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# estimating query 86: predicted 70312.5019513337, true_card 77059, qerror 0.9124502258183171, latency 0.0007183551788330078
# ========================
# 0.9875505579300649
# posts.Id 91976.0
# postLinks.RelatedPostId 10807.0
# comments.PostId 153297.0
# estimating query 87: predicted 43099.2555518554, true_card 32792, qerror 1.3143222600590205, latency 0.002534627914428711
# ========================
# 0.9639424057206514
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 153297.0
# estimating query 88: predicted 25362.732625601482, true_card 142137, qerror 0.1784386375511055, latency 0.001363992691040039
# ========================
# 0.9760942343459389
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 10807.0
# estimating query 89: predicted 55067.940928359014, true_card 8528, qerror 6.457310146383562, latency 0.000949859619140625
# ========================
# 0.9639424057206514
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 10807.0
# key 153297.0
# estimating query 90: predicted 103197.83912732697, true_card 25033, qerror 4.122471902182198, latency 0.0014438629150390625
# ========================
# 0.8963762450797494
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# comments.UserId 170648.0
# estimating query 91: predicted 49823918.595497474, true_card 36980622, qerror 1.347298014497903, latency 0.007185459136962891
# ========================
# 0.916061462002045
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 92: predicted 10379396.346368738, true_card 242937, qerror 42.72464197042335, latency 0.003493070602416992
# ========================
# 0.8974362104245073
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 93: predicted 140066.8967822857, true_card 42543, qerror 3.292360594746156, latency 0.00237274169921875
# ========================
# 0.9758701571887733
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# estimating query 94: predicted 2798236.3089985843, true_card 84481, qerror 33.12267029271178, latency 0.002359628677368164
# ========================
# 0.9560288824069164
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 95: predicted 68867.10349724685, true_card 40496, qerror 1.7005902681066487, latency 0.0020132064819335938
# ========================
# 0.9770241241231732
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 96: predicted 28474.707672126802, true_card 244, qerror 116.69962160707706, latency 0.002622842788696289
# ========================
# 0.8951658267571954
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 97: predicted 10288204399.262348, true_card 272870860, qerror 37.703565705998614, latency 0.010758399963378906
# ========================
# 0.8769654227247746
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# comments.UserId 170648.0
# estimating query 98: predicted 48744993.045880884, true_card 256660, qerror 189.92049032136245, latency 0.004335165023803711
# ========================
# 0.8962243607816995
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 99: predicted 10154632.89493065, true_card 2489, qerror 4079.8042968785253, latency 0.0040132999420166016
# ========================
# 0.9547379123678195
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# estimating query 100: predicted 2737641.1424049186, true_card 1799, qerror 1521.7571664285263, latency 0.0044558048248291016
# ========================
# 0.8757812157338609
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 101: predicted 10065415688.559753, true_card 42036, qerror 239447.51376343498, latency 0.004950523376464844
# ========================
# 0.992563277376707
# posts.Id 91976.0
# votes.PostId 328064.0
# estimating query 102: predicted 194906.34223420607, true_card 289619, qerror 0.6729749851846946, latency 0.0016674995422363281
# ========================
# 0.992563277376707
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# badges.UserId 72862.0
# estimating query 103: predicted 3611024.3743131757, true_card 3660301, qerror 0.9865375482270927, latency 0.0007801055908203125
# ========================
# 0.9925632773767067
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 104: predicted 71498.84193726079, true_card 89863, qerror 0.7956427221132256, latency 0.0009324550628662109
# ========================
# 0.9999999999999997
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 105: predicted 47733.7567245126, true_card 79851, qerror 0.5977853342414321, latency 0.0006802082061767578
# ========================
# 0.992563277376707
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# key 91976.0
# key 328064.0
# estimating query 106: predicted 85494329.45491423, true_card 16049150, qerror 5.327031615687699, latency 0.007310628890991211
# ========================
# 0.9925632773767067
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 328064.0
# estimating query 107: predicted 33517.72132673877, true_card 284619, qerror 0.11776347090931656, latency 0.003032207489013672
# ========================
# 0.9925632773767067
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# badges.UserId 72862.0
# estimating query 108: predicted 3611024.3743131747, true_card 3660301, qerror 0.9865375482270925, latency 0.001880645751953125
# ========================
# 0.9925632773767067
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# key 91976.0
# key 328064.0
# estimating query 109: predicted 85494329.4549142, true_card 16049150, qerror 5.327031615687697, latency 0.0013124942779541016
# ========================
# 0.0014857701346776427
# posts.Id 91976.0
# votes.PostId 328064.0
# estimating query 110: predicted 291.7557287795331, true_card 93000, qerror 0.0031371583739734743, latency 0.0048983097076416016
# ========================
# 0.0014583065247192922
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# badges.UserId 72862.0
# estimating query 111: predicted 5305.435457877321, true_card 206773, qerror 0.025658260304185367, latency 0.0036928653717041016
# ========================
# 0.0014254185625030534
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 112: predicted 102.67937452229889, true_card 9872, qerror 0.010401071163117797, latency 0.002041339874267578
# ========================
# 0.9416466814991385
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 113: predicted 44948.33361512449, true_card 60506, qerror 0.7428739896063942, latency 0.003943681716918945
# ========================
# 0.0014583065247192922
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# key 91976.0
# key 328064.0
# estimating query 114: predicted 125611.07318025792, true_card 2112679, qerror 0.05945582513020574, latency 0.0039293766021728516
# ========================
# 0.0014254185625030534
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 328064.0
# estimating query 115: predicted 48.13474691327436, true_card 59978, qerror 0.000802540046571649, latency 0.005045175552368164
# ========================
# 0.0013990705167897305
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# badges.UserId 72862.0
# estimating query 116: predicted 5089.930136104799, true_card 80977, qerror 0.06285649179526037, latency 0.003495454788208008
# ========================
# 0.0013990705167897305
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# badges.UserId 72862.0
# key 91976.0
# key 328064.0
# estimating query 117: predicted 120508.786109041, true_card 595820, qerror 0.2022570341865681, latency 0.00509953498840332
# ========================
# 0.14222797669154283
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# estimating query 118: predicted 407828.3218334879, true_card 1187068, qerror 0.3435593595594253, latency 0.0016183853149414062
# ========================
# 1
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 119: predicted 993606.9525606718, true_card 1056687, qerror 0.940303942946844, latency 0.0025091171264648438
# ========================
# 1
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 120: predicted 29144.324043872843, true_card 34789, qerror 0.8377453805476686, latency 0.0010864734649658203
# ========================
# 0.14222797669154283
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# badges.UserId 72862.0
# estimating query 121: predicted 517436.72393340553, true_card 1486002, qerror 0.34820728635183906, latency 0.0025243759155273438
# ========================
# 0.14222797669154283
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 122: predicted 10245.327281703923, true_card 37048, qerror 0.2765419801798727, latency 0.002086639404296875
# ========================
# 1
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 123: predicted 47733.75672451261, true_card 79851, qerror 0.5977853342414323, latency 0.0010101795196533203
# ========================
# 0.14222797669154283
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 124: predicted 76728580.32991843, true_card 232039659, qerror 0.3306701132926524, latency 0.003242969512939453
# ========================
# 0.14222797669154283
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# estimating query 125: predicted 407828.3218334879, true_card 1187068, qerror 0.3435593595594253, latency 0.0024313926696777344
# ========================
# 1
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 126: predicted 993606.9525606718, true_card 1056687, qerror 0.940303942946844, latency 0.0012841224670410156
# ========================
# 0.14222797669154283
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# badges.UserId 72862.0
# estimating query 127: predicted 517436.72393340553, true_card 1486002, qerror 0.34820728635183906, latency 0.002785205841064453
# ========================
# 0.14222797669154283
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 128: predicted 76728580.32991843, true_card 232039659, qerror 0.3306701132926524, latency 0.002720355987548828
# ========================
# 0.9972076553183219
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# estimating query 129: predicted 2859420.0244441857, true_card 368186, qerror 7.766237783197041, latency 0.002063751220703125
# ========================
# 0.9466756834604446
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 130: predicted 940623.5409064236, true_card 956304, qerror 0.9836030602260616, latency 0.0011837482452392578
# ========================
# 0.9661748295102294
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 131: predicted 28158.512314279724, true_card 28260, qerror 0.9964087867756448, latency 0.0017774105072021484
# ========================
# 0.9440322386504598
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# badges.UserId 72862.0
# estimating query 132: predicted 3434464.5843777843, true_card 413771, qerror 8.300399458584058, latency 0.0023810863494873047
# ========================
# 0.9634769363634752
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 133: predicted 69403.62065914269, true_card 38786, qerror 1.7893987691214017, latency 0.0018923282623291016
# ========================
# 0.914654217068875
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 134: predicted 43659.88188461523, true_card 67113, qerror 0.650542843929123, latency 0.0010750293731689453
# ========================
# 0.9440322386504598
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 135: predicted 509282738.4756829, true_card 19383482, qerror 26.274058421272446, latency 0.0037755966186523438
# ========================
# 0.9634769363634752
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# estimating query 136: predicted 2762699.6546154968, true_card 239532, qerror 11.533739352635543, latency 0.0022399425506591797
# ========================
# 0.914654217068875
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 137: predicted 908806.7892685721, true_card 475290, qerror 1.9121100575828907, latency 0.00131988525390625
# ========================
# 0.9121001872302682
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# badges.UserId 72862.0
# estimating query 138: predicted 3318293.2342701266, true_card 298796, qerror 11.105547712386132, latency 0.0036089420318603516
# ========================
# 0.9121001872302682
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 139: predicted 492056163.0192457, true_card 6672465, qerror 73.74428536069439, latency 0.0030133724212646484
# ========================
# 0.9033217820342858
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 140: predicted 237580889.6645462, true_card 235010920, qerror 1.0109355329724516, latency 0.0025005340576171875
# ========================
# 0.9685800411526212
# comments.UserId 170648.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 141: predicted 10974455.92606182, true_card 10967392, qerror 1.000644084396894, latency 0.0019614696502685547
# ========================
# 0.9811460344552407
# comments.UserId 170648.0
# users.Id 40325.00000000001
# estimating query 142: predicted 153131.8646830459, true_card 64129, qerror 2.387872330506415, latency 0.001880645751953125
# ========================
# 0.8971381412620032
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 143: predicted 12566227.226276588, true_card 12470361, qerror 1.0076875261491298, latency 0.002167224884033203
# ========================
# 0.9087772742150293
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# estimating query 144: predicted 205015.19465191686, true_card 140071, qerror 1.463651966873349, latency 0.0024034976959228516
# ========================
# 0.9744296519402993
# votes.UserId 29638.0
# users.Id 40325.00000000001
# estimating query 145: predicted 28399.09353410631, true_card 20007, qerror 1.4194578664520572, latency 0.002429962158203125
# ========================
# 0.8859692719436326
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 146: predicted 51634631262.59445, true_card 52988984588, qerror 0.9744408515102542, latency 0.0031113624572753906
# ========================
# 0.8974635041852157
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 147: predicted 236040115.5008259, true_card 2038871, qerror 115.77000972637597, latency 0.002868175506591797
# ========================
# 0.9622985464372413
# comments.UserId 170648.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 148: predicted 10903283.711092686, true_card 221701, qerror 49.18012869176362, latency 0.0027475357055664062
# ========================
# 0.8913199659395004
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 149: predicted 12484731.958399516, true_card 425598, qerror 29.33456444438065, latency 0.0025892257690429688
# ========================
# 0.88022352965776
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 150: predicted 51299767183.60661, true_card 19402569, qerror 2643.9677747625387, latency 0.003061532974243164
# ========================
# 1
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 151: predicted 263008038.0985751, true_card 263105194, qerror 0.999630733624267, latency 0.001931905746459961
# ========================
# 0.0052079373571003885
# comments.UserId 170648.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 152: predicted 59008.31791162541, true_card 505601, qerror 0.11670925870721263, latency 0.0020296573638916016
# ========================
# 0.9364960130875943
# comments.UserId 170648.0
# users.Id 40325.00000000001
# estimating query 153: predicted 146163.13547245308, true_card 19556, qerror 7.4740813802645265, latency 0.002260446548461914
# ========================
# 0.0052079373571003885
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 154: predicted 72947.6556614544, true_card 593512, qerror 0.12290847642752699, latency 0.0009744167327880859
# ========================
# 0.9364960130875943
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# estimating query 155: predicted 211268.39090440143, true_card 62790, qerror 3.364682129390053, latency 0.0013358592987060547
# ========================
# 0.004877212571334457
# votes.UserId 29638.0
# users.Id 40325.00000000001
# estimating query 156: predicted 142.1430636098217, true_card 40, qerror 3.5535765902455423, latency 0.002510547637939453
# ========================
# 0.0052079373571003885
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 157: predicted 303520600.07977104, true_card 2724339544, qerror 0.11141070897283538, latency 0.0038695335388183594
# ========================
# 0.9364960130875943
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 158: predicted 246305979.08930567, true_card 157483, qerror 1564.0163007391634, latency 0.0026984214782714844
# ========================
# 0.004877212571334457
# comments.UserId 170648.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 159: predicted 55261.05446324247, true_card 200, qerror 276.3052723162124, latency 0.0032668113708496094
# ========================
# 0.004877212571334457
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 160: predicted 68315.18869103871, true_card 440, qerror 155.26179247963344, latency 0.0029523372650146484
# ========================
# 0.004877212571334457
# postHistory.UserId 277348.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 161: predicted 284245831.8646598, true_card 6299, qerror 45125.5487957866, latency 0.0035352706909179688
# ========================
# 0.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 162: predicted 0.0, true_card 2201378, qerror 0.0, latency 0.0022089481353759766
# ========================
# 0.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# badges.UserId 72862.0
# estimating query 163: predicted 0.0, true_card 3321285, qerror 0.0, latency 0.0007789134979248047
# ========================
# 0.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 164: predicted 0.0, true_card 24049, qerror 0.0, latency 0.0010790824890136719
# ========================
# 1
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 165: predicted 993606.9525606718, true_card 1056687, qerror 0.940303942946844, latency 0.0031461715698242188
# ========================
# 0.982120272783633
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 166: predicted 28623.23148006299, true_card 33891, qerror 0.844567332922103, latency 0.001674652099609375
# ========================
# 0.982120272783633
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 167: predicted 46880.2901752659, true_card 77791, qerror 0.6026441384641655, latency 0.001613616943359375
# ========================
# 0.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 168: predicted 0.0, true_card 596251188, qerror 0.0, latency 0.0019559860229492188
# ========================
# 0.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 169: predicted 0.0, true_card 2169982, qerror 0.0, latency 0.002251863479614258
# ========================
# 0.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# badges.UserId 72862.0
# estimating query 170: predicted 0.0, true_card 3271463, qerror 0.0, latency 0.0020797252655029297
# ========================
# 0.982120272783633
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 171: predicted 975841.5312886013, true_card 1012835, qerror 0.9634753254859887, latency 0.0013184547424316406
# ========================
# 0.0
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 172: predicted 0.0, true_card 593169291, qerror 0.0, latency 0.002490997314453125
# ========================
# 0.004870808241253043
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 173: predicted 55188.49046726049, true_card 346990, qerror 0.15904922466716762, latency 0.0021195411682128906
# ========================
# 0.9173001348211468
# users.Id 40325.00000000001
# comments.UserId 170648.0
# badges.UserId 72862.0
# estimating query 174: predicted 14362954.238127144, true_card 10238947, qerror 1.4027765001740067, latency 0.001552581787109375
# ========================
# 0.8586907731021387
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 175: predicted 134019.72250162053, true_card 92013, qerror 1.456530300083907, latency 0.0010693073272705078
# ========================
# 0.005309939523995319
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 176: predicted 5275.992828718453, true_card 41772, qerror 0.12630453003730854, latency 0.0007448196411132812
# ========================
# 0.004970669797049756
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 177: predicted 144.86681128030975, true_card 913, qerror 0.1586712062215879, latency 0.0012903213500976562
# ========================
# 0.9361066683693058
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 178: predicted 44683.88797613445, true_card 68895, qerror 0.648579548242027, latency 0.004030942916870117
# ========================
# 0.004870808241253043
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 179: predicted 13770715.736204589, true_card 91539518, qerror 0.15043465420262087, latency 0.0020570755004882812
# ========================
# 0.004559596074985143
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 180: predicted 51662.3139436384, true_card 70700, qerror 0.73072579835415, latency 0.0014760494232177734
# ========================
# 0.8586907731021387
# users.Id 40325.00000000001
# comments.UserId 170648.0
# badges.UserId 72862.0
# estimating query 181: predicted 13445257.239794001, true_card 1984289, qerror 6.775856359529283, latency 0.0035276412963867188
# ========================
# 0.004970669797049756
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 182: predicted 4938.892069231981, true_card 18346, qerror 0.2692081145335212, latency 0.0024051666259765625
# ========================
# 0.004559596074985143
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 183: predicted 12890858.828879248, true_card 3169724, qerror 4.066871067916086, latency 0.0027306079864501953
# ========================
# 0.004777125144450298
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 184: predicted 54127.018030088206, true_card 345663, qerror 0.15658898415534264, latency 0.0018415451049804688
# ========================
# 0.9173001348211468
# users.Id 40325.00000000001
# comments.UserId 170648.0
# badges.UserId 72862.0
# estimating query 185: predicted 14362954.238127144, true_card 10238947, qerror 1.4027765001740067, latency 0.0019009113311767578
# ========================
# 0.9137742446563039
# users.Id 40325.00000000001
# comments.UserId 170648.0
# estimating query 186: predicted 142616.8471049811, true_card 46989, qerror 3.0351113474426166, latency 0.001094818115234375
# ========================
# 0.005207810359018133
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 187: predicted 5174.516580337906, true_card 41442, qerror 0.12486165195545355, latency 0.002093791961669922
# ========================
# 0.005187792737055384
# users.Id 40325.00000000001
# votes.UserId 29638.0
# estimating query 188: predicted 151.19471260119212, true_card 381, qerror 0.3968365160136276, latency 0.0017423629760742188
# ========================
# 0.9961562306261621
# users.Id 40325.00000000001
# badges.UserId 72862.0
# estimating query 189: predicted 47550.2791723167, true_card 57353, qerror 0.829080940357378, latency 0.0015649795532226562
# ========================
# 0.004777125144450298
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 190: predicted 13505855.525853533, true_card 91443369, qerror 0.14769639038401497, latency 0.002112865447998047
# ========================
# 0.004758762977125069
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# estimating query 191: predicted 53918.966255886975, true_card 4204, qerror 12.825634218812315, latency 0.0027246475219726562
# ========================
# 0.9137742446563039
# users.Id 40325.00000000001
# comments.UserId 170648.0
# badges.UserId 72862.0
# estimating query 192: predicted 14307746.354508795, true_card 261931, qerror 54.6241046478225, latency 0.0011677742004394531
# ========================
# 0.005187792737055384
# users.Id 40325.00000000001
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 193: predicted 5154.626931981987, true_card 3236, qerror 1.5929007824418995, latency 0.002833843231201172
# ========================
# 0.004758762977125069
# users.Id 40325.00000000001
# comments.UserId 170648.0
# votes.UserId 29638.0
# badges.UserId 72862.0
# estimating query 194: predicted 13453942.132015778, true_card 52313, qerror 257.1816208593615, latency 0.002553224563598633
# ========================
# 1
# comments.PostId 153297.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 195: predicted 32373.410186804223, true_card 35295, qerror 0.9172236913671689, latency 0.0010929107666015625
# ========================
# 0.899758235016673
# postHistory.PostId 259700.0
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 196: predicted 248784.82731910213, true_card 642583, qerror 0.3871637240933889, latency 0.0008401870727539062
# ========================
# 1
# votes.PostId 328064.0
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 197: predicted 661803.7574180634, true_card 865125, qerror 0.7649805027228012, latency 0.00041222572326660156
# ========================
# 0.899758235016673
# postHistory.PostId 259700.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 198: predicted 30741.026249286413, true_card 59346, qerror 0.5179966004328247, latency 0.0008187294006347656
# ========================
# 1
# votes.PostId 328064.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 199: predicted 69284.4791807575, true_card 69701, qerror 0.994024177282356, latency 0.00030875205993652344
# ========================
# 0.899758235016673
# postHistory.PostId 259700.0
# posts.Id 91976.0
# votes.PostId 328064.0
# estimating query 200: predicted 800313.6381591125, true_card 1057588, qerror 0.7567347947963787, latency 0.008509159088134766
# ========================
# 0.899758235016673
# comments.PostId 153297.0
# posts.Id 91976.0
# postHistory.PostId 259700.0
# postLinks.PostId 9502.0
# estimating query 201: predicted 107737.21675237826, true_card 206322, qerror 0.522179974759736, latency 0.0019259452819824219
# ========================
# 1
# comments.PostId 153297.0
# posts.Id 91976.0
# votes.PostId 328064.0
# postLinks.PostId 9502.0
# estimating query 202: predicted 293133.48663667217, true_card 282841, qerror 1.0363896558019245, latency 0.00039505958557128906
# ========================
# 0.899758235016673
# votes.PostId 328064.0
# posts.Id 91976.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# estimating query 203: predicted 2800763.2452816623, true_card 3460999, qerror 0.8092354968266857, latency 0.0025398731231689453
# ========================
# 0.899758235016673
# votes.PostId 328064.0
# posts.Id 91976.0
# postHistory.PostId 259700.0
# postLinks.PostId 9502.0
# estimating query 204: predicted 305884.76058022224, true_card 371988, qerror 0.8222973874969682, latency 0.002669811248779297
# ========================
# 0.899758235016673
# comments.PostId 153297.0
# posts.Id 91976.0
# votes.PostId 328064.0
# ...
# ========================
# 0.007156221198227888
# posts.Id 91976.0
# postLinks.PostId 9502.0
# votes.PostId 328064.0
# estimating query 2538: predicted 495.81505862151556, true_card 61687, qerror 0.008037593960178247, latency 0.0018527507781982422
# ========================
# 0.0072963822675624615
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# estimating query 2539: predicted 411.6372513665053, true_card 10453, qerror 0.0393798193213915, latency 0.0015327930450439453
# ========================
# 0.0
# posts.Id 91976.0
# postHistory.PostId 259700.0
# votes.PostId 328064.0
# estimating query 2540: predicted 0.0, true_card 175223, qerror 0.0, latency 0.002202272415161133
# ========================
# 0.0
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# estimating query 2541: predicted 0.0, true_card 38044, qerror 0.0, latency 0.0027403831481933594
# ========================
# 0.007298885415041431
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# key 91976.0
# key 328064.0
# estimating query 2542: predicted 246.4749733475259, true_card 146996, qerror 0.0016767461247076511, latency 0.0019690990447998047
# ========================
# 0.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# votes.PostId 328064.0
# estimating query 2543: predicted 0.0, true_card 90846, qerror 0.0, latency 0.0016591548919677734
# ========================
# 0.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# estimating query 2544: predicted 0.0, true_card 51304, qerror 0.0, latency 0.0021364688873291016
# ========================
# 0.007156221198227888
# posts.Id 91976.0
# postLinks.PostId 9502.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2545: predicted 2097.7280709798047, true_card 251465, qerror 0.008342027999840155, latency 0.001984834671020508
# ========================
# 0.0072963822675624615
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 153297.0
# estimating query 2546: predicted 659.0149124164257, true_card 33366, qerror 0.019751091303015816, latency 0.0025262832641601562
# ========================
# 0.0
# posts.Id 91976.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2547: predicted 0.0, true_card 668362, qerror 0.0, latency 0.0021276473999023438
# ========================
# 0.0
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# key 153297.0
# estimating query 2548: predicted 0.0, true_card 116096, qerror 0.0, latency 0.0022749900817871094
# ========================
# 0.007298885415041431
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 153297.0
# key 328064.0
# estimating query 2549: predicted 390.3385436016176, true_card 405572, qerror 0.0009624395757143431, latency 0.0022373199462890625
# ========================
# 0.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2550: predicted 0.0, true_card 458451, qerror 0.0, latency 0.0022389888763427734
# ========================
# 0.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# votes.PostId 328064.0
# estimating query 2551: predicted 0.0, true_card 87842, qerror 0.0, latency 0.0014617443084716797
# ========================
# 0.0
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 259700.0
# estimating query 2552: predicted 0.0, true_card 12124, qerror 0.0, latency 0.001657724380493164
# ========================
# 0.0071562211982278846
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 328064.0
# estimating query 2553: predicted 646.3890721683894, true_card 60963, qerror 0.010602973478476935, latency 0.004399299621582031
# ========================
# 0.0
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# key 328064.0
# estimating query 2554: predicted 0.0, true_card 172157, qerror 0.0, latency 0.002361297607421875
# ========================
# 0.0
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2555: predicted 0.0, true_card 438690, qerror 0.0, latency 0.002203702926635742
# ========================
# 0.0
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 259700.0
# key 153297.0
# estimating query 2556: predicted 0.0, true_card 50824, qerror 0.0, latency 0.0026488304138183594
# ========================
# 0.0071562211982278846
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 153297.0
# key 328064.0
# estimating query 2557: predicted 1285.0813806383555, true_card 249157, qerror 0.005157717345442254, latency 0.002615690231323242
# ========================
# 0.0
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# key 153297.0
# key 328064.0
# estimating query 2558: predicted 0.0, true_card 659522, qerror 0.0, latency 0.002728700637817383
# ========================
# 0.0
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 259700.0
# key 328064.0
# estimating query 2559: predicted 0.0, true_card 87188, qerror 0.0, latency 0.0031278133392333984
# ========================
# 0.0
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 328064.0
# key 259700.0
# key 153297.0
# estimating query 2560: predicted 0.0, true_card 436286, qerror 0.0, latency 0.003457784652709961
# ========================
# 0.33597127234207513
# posts.Id 91976.0
# comments.PostId 153297.0
# estimating query 2561: predicted 24020.03670650935, true_card 169983, qerror 0.14130846441414346, latency 0.0018146038055419922
# ========================
# 0.9531259438137855
# posts.Id 91976.0
# postLinks.PostId 9502.0
# comments.PostId 153297.0
# estimating query 2562: predicted 30855.937138768593, true_card 33456, qerror 0.9222841086432506, latency 0.0012323856353759766
# ========================
# 0.9430632760868171
# posts.Id 91976.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# estimating query 2563: predicted 260758.7518083654, true_card 679915, qerror 0.38351669224589163, latency 0.0012154579162597656
# ========================
# 0.987550557930065
# posts.Id 91976.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2564: predicted 653564.6698784218, true_card 853748, qerror 0.7655241006461179, latency 0.0008265972137451172
# ========================
# 0.3283475331026462
# posts.Id 91976.0
# postLinks.PostId 9502.0
# estimating query 2565: predicted 3119.958259541344, true_card 10494, qerror 0.29730877258827365, latency 0.0018737316131591797
# ========================
# 0.32488099004395976
# posts.Id 91976.0
# postHistory.PostId 259700.0
# estimating query 2566: predicted 28348.80330054993, true_card 289244, qerror 0.0980099960605922, latency 0.0014972686767578125
# ========================
# 0.3402066553901613
# posts.Id 91976.0
# votes.PostId 328064.0
# estimating query 2567: predicted 66805.24689678135, true_card 318561, qerror 0.20970943366194025, latency 0.0014729499816894531
# ========================
# 0.3402066553901612
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# estimating query 2568: predicted 24506.630896151393, true_card 89639, qerror 0.27339250656691166, latency 0.001706838607788086
# ========================
# 0.9216636235122149
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# estimating query 2569: predicted 31489.442986733437, true_card 59178, qerror 0.5321140117397248, latency 0.0013518333435058594
# ========================
# 0.965141415961088
# posts.Id 91976.0
# postLinks.PostId 9502.0
# votes.PostId 328064.0
# estimating query 2570: predicted 66869.32034064281, true_card 68029, qerror 0.9829531573394112, latency 0.0008518695831298828
# ========================
# 0.9549518943754186
# posts.Id 91976.0
# postHistory.PostId 259700.0
# votes.PostId 328064.0
# estimating query 2571: predicted 849407.0908285332, true_card 1179398, qerror 0.7202039437310672, latency 0.001413106918334961
# ========================
# 0.3242597895104788
# posts.Id 91976.0
# postLinks.PostId 9502.0
# comments.PostId 153297.0
# estimating query 2572: predicted 10497.395172909528, true_card 32546, qerror 0.3225402560348285, latency 0.0017600059509277344
# ========================
# 0.32083640297878435
# posts.Id 91976.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# estimating query 2573: predicted 88711.86281643718, true_card 659401, qerror 0.13453401316715805, latency 0.0019249916076660156
# ========================
# 0.33597127234207513
# posts.Id 91976.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2574: predicted 222347.0504205128, true_card 803828, qerror 0.27661023306044674, latency 0.0014233589172363281
# ========================
# 0.335971272342075
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 153297.0
# estimating query 2575: predicted 8839.894893849705, true_card 167410, qerror 0.05280386412908252, latency 0.0022039413452148438
# ========================
# 0.9101894256233332
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# estimating query 2576: predicted 108986.24943653513, true_card 204137, qerror 0.5338877784847192, latency 0.0015845298767089844
# ========================
# 0.9531259438137855
# posts.Id 91976.0
# postLinks.PostId 9502.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2577: predicted 279393.13111400383, true_card 267839, qerror 1.0431383447294973, latency 0.0014777183532714844
# ========================
# 0.9430632760868171
# posts.Id 91976.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2578: predicted 2935562.9755252264, true_card 3807034, qerror 0.7710892457291494, latency 0.0014219284057617188
# ========================
# 0.31355609874986745
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# estimating query 2579: predicted 10712.918078615754, true_card 58730, qerror 0.1824096386619403, latency 0.0017533302307128906
# ========================
# 0.3283475331026462
# posts.Id 91976.0
# postLinks.PostId 9502.0
# votes.PostId 328064.0
# estimating query 2580: predicted 22749.38782130337, true_card 65064, qerror 0.34964631472555285, latency 0.0017545223236083984
# ========================
# 0.32834753310264614
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# estimating query 2581: predicted 18524.25915514696, true_card 10354, qerror 1.789092056707259, latency 0.0020101070404052734
# ========================
# 0.32488099004395976
# posts.Id 91976.0
# postHistory.PostId 259700.0
# votes.PostId 328064.0
# estimating query 2582: predicted 288973.9454354622, true_card 1156329, qerror 0.24990633758684788, latency 0.001554727554321289
# ========================
# 0.32488099004395965
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# estimating query 2583: predicted 6158.428042882626, true_card 284839, qerror 0.021620733266450965, latency 0.0019843578338623047
# ========================
# 0.3402066553901612
# users.Id 40325.00000000001
# posts.OwnerUserId 90361.0
# key 91976.0
# key 328064.0
# estimating query 2584: predicted 11488.387822493984, true_card 312661, qerror 0.03674391056925547, latency 0.0023660659790039062
# ========================
# 0.9216636235122149
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# votes.PostId 328064.0
# estimating query 2585: predicted 313331.7882978974, true_card 396051, qerror 0.7911400003986794, latency 0.0013074874877929688
# ========================
# 0.30965250026280616
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# estimating query 2586: predicted 37077.84740432147, true_card 198082, qerror 0.18718433479226515, latency 0.001970052719116211
# ========================
# 0.32425978951047874
# posts.Id 91976.0
# postLinks.PostId 9502.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2587: predicted 95051.40267528004, true_card 248612, qerror 0.38232829740833124, latency 0.002347707748413086
# ========================
# 0.3242597895104786
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 153297.0
# estimating query 2588: predicted 29287.39599272748, true_card 32154, qerror 0.9108476703591305, latency 0.0025246143341064453
# ========================
# 0.32083640297878435
# posts.Id 91976.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2589: predicted 998698.0615906273, true_card 3482755, qerror 0.2867551870833944, latency 0.002124309539794922
# ========================
# 0.32083640297878424
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# key 153297.0
# estimating query 2590: predicted 9055.740901154764, true_card 649110, qerror 0.013951011232541118, latency 0.0020999908447265625
# ========================
# 0.335971272342075
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 153297.0
# key 328064.0
# estimating query 2591: predicted 17967.474440375714, true_card 790217, qerror 0.02273739294443895, latency 0.002779245376586914
# ========================
# 0.9101894256233333
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2592: predicted 1400571.1122473571, true_card 1706906, qerror 0.8205320692805328, latency 0.0018115043640136719
# ========================
# 0.31355609874986745
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# votes.PostId 328064.0
# estimating query 2593: predicted 106597.55972424574, true_card 387888, qerror 0.27481530680053456, latency 0.0019378662109375
# ========================
# 0.3135560987498674
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 259700.0
# estimating query 2594: predicted 17642.84842430459, true_card 57968, qerror 0.30435496177726656, latency 0.002434968948364258
# ========================
# 0.32834753310264614
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 328064.0
# estimating query 2595: predicted 29658.146582103498, true_card 64156, qerror 0.4622817286318271, latency 0.0020759105682373047
# ========================
# 0.32488099004395965
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# key 328064.0
# estimating query 2596: predicted 13784.025150160884, true_card 1137071, qerror 0.012122396182965605, latency 0.0027289390563964844
# ========================
# 0.30965250026280616
# posts.Id 91976.0
# postLinks.PostId 9502.0
# postHistory.PostId 259700.0
# comments.PostId 153297.0
# votes.PostId 328064.0
# estimating query 2597: predicted 476483.6137337515, true_card 1586326, qerror 0.3003692896250528, latency 0.0024793148040771484
# ========================
# 0.30965250026280605
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 259700.0
# key 153297.0
# estimating query 2598: predicted 28693.437507918203, true_card 195525, qerror 0.14675073524059942, latency 0.003037691116333008
# ========================
# 0.3242597895104786
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 153297.0
# key 328064.0
# estimating query 2599: predicted 58229.08577683667, true_card 245765, qerror 0.23692993622703262, latency 0.0028960704803466797
# ========================
# 0.32083640297878424
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 259700.0
# key 153297.0
# key 328064.0
# estimating query 2600: predicted 22385.083813471312, true_card 3429589, qerror 0.006527045606185264, latency 0.0029044151306152344
# ========================
# 0.3135560987498674
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 259700.0
# key 328064.0
# estimating query 2601: predicted 38546.98460467656, true_card 383348, qerror 0.1005535038781383, latency 0.0029861927032470703
# ========================
# 0.30965250026280605
# posts.OwnerUserId 90361.0
# users.Id 40325.00000000001
# key 91976.0
# key 9502.0
# key 328064.0
# key 259700.0
# key 153297.0
# estimating query 2602: predicted 80965.17632210221, true_card 1570429, qerror 0.05155608838228421, latency 0.0031909942626953125

# %%
for i in [50, 90, 95, 99, 100]:
    print(f"q-error {i}% percentile is {np.percentile(qerror, i)}")
print(f"total inference time: {np.sum(latency)}")
# Out:
# q-error 50% percentile is 0.4861976823827677
# q-error 90% percentile is 49.4112299823222
# q-error 95% percentile is 798.469580730671
# q-error 99% percentile is 360148.0710562391
# q-error 100% percentile is 114172012572.37447
# total inference time: 5.603515863418579

# %%
with open("stats_CEB_join_hist.txt", "w") as f:
    for p in pred:
        f.write(str(p)+"\n")
